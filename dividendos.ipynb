# %%
# atualizado em
from datetime import date
print(date.today())
# Out:
# 2022-03-03

# %%
import pandas as pd

from utils import yahoo_symbol, create_rank_dataframe

file = open('IDIVDia_03-03-22.csv', encoding='latin-1')
file.readline()

df = pd.read_csv(file, encoding='latin-1', sep=';')

idiv_codes = df.index[:-2].to_list()

# %%
create_rank_dataframe(idiv_codes)
# Out:
#             CTL  SOFG    QR    CR   ROA   ROE   P/B   P/E   P/S    DY   DPR  \
# SYNE3.SA    2.0  36.0   4.0   7.0   3.0   5.0   3.0   1.0   2.0  35.0  40.0
# ROMI3.SA    1.0   8.0  24.0  12.0  17.0  13.0  17.0   9.0   6.0  35.0   9.0
# CSNA3.SA   15.0  15.0  25.0  17.0   5.0   1.0  33.0   3.0  11.0  35.0   3.0
# SAPR4.SA   29.0  10.0  11.0  19.0  11.0  27.0   9.0  11.0  17.0  10.0  11.0
# JHSF3.SA   19.0  21.0  10.0  13.0  12.0  12.0  11.0   7.0  26.0  35.0   5.0
# BRAP4.SA   13.0  20.0   1.0   1.0  42.0   6.0  12.0   2.0  42.0  35.0   4.0
# CPLE3.SA   28.0   4.5  18.5  29.5  15.5  17.5   8.0   4.0   9.0  15.0  31.0
# TRPL4.SA   26.0  14.0   3.0   5.0  10.0  19.0  21.0  12.0  36.0   3.0  32.0
# UNIP6.SA   36.0  31.0   8.0   9.0   1.0   2.0  40.0  15.0  23.0   1.0  22.0
# WIZS3.SA    6.0  37.0  22.0  11.0   4.0   4.0  39.0  20.0  19.0   4.0  27.0
# CMIG4.SA   31.0  10.0  20.5  27.5  22.5  15.5  19.0  13.0   7.0  16.0  14.5
# ...
