# %%
# atualizado em
from datetime import date
print(date.today())
# Out:
# 2021-03-27

# %%
def yahoo_symbol(name: str) -> str:
    return name.upper() + '.SA'

# %%
from yahooquery import Ticker

idiv = [
'vivt3', 
'csna3', 
'bbse3', 
'klbn11', 
'cyre3', 
'itsa4', 
'itub3', 
'taee11', 
'trpl4', 
'brdt3', 
'itub4', 
'ccro3', 
'mrve3', 
'tiet11', 
'sanb11', 
'cmig4', 
'brap4', 
'pssa3', 
'egie3', 
'sapr11', 
'qual3', 
'enbr3', 
'cple6', 
'ciel3', 
'slce3', 
'cple3', 
'bbas3', 
'csmg3', 
'brsr6', 
'unip6', 
'mypk3', 
'smls3', 
'abcb4', 
'romi3', 
'dirr3', 
'sapr4', 
'leve3', 
'tgma3', 
'wizs3'
]

ticker_idiv = {code : Ticker(yahoo_symbol(code)) for code in idiv}

# %%
dict_idiv_summary_detail = {yahoo_symbol(code) : ticker_idiv[code].summary_detail[yahoo_symbol(code)] 
                            for code in ticker_idiv.keys()}

dict_idiv_financial_data = {yahoo_symbol(code) : ticker_idiv[code].financial_data[yahoo_symbol(code)] 
                            for code in ticker_idiv.keys()}

dict_idiv_key_stats = {yahoo_symbol(code) : ticker_idiv[code].key_stats[yahoo_symbol(code)]
                      for code in ticker_idiv.keys()}

# %%
import pandas as pd

# %%
dataframe_idiv_financial_data = pd.DataFrame(dict_idiv_financial_data).transpose()
dataframe_idiv_summary_detail = pd.DataFrame(dict_idiv_summary_detail).transpose()
dataframe_idiv_key_stats = pd.DataFrame(dict_idiv_key_stats).transpose()

# %%
parameters_summary_details = [
    'previousClose',
    'fiftyTwoWeekLow',
    'fiftyTwoWeekHigh',
    'fiveYearAvgDividendYield',
    'payoutRatio'
]

parameters_financial_data = [
    'quickRatio',
    'returnOnAssets',
    'returnOnEquity',
    'debtToEquity',
    'grossProfits',
    'earningsGrowth'
]

parameters_key_stats = [
    'floatShares',
    'priceToBook',
    'enterpriseToRevenue',
    'enterpriseToEbitda',
    'bookValue'
]

view_dataframe_idiv_summary_detail = dataframe_idiv_summary_detail[parameters_summary_details]
view_dataframe_idiv_financial_data = dataframe_idiv_financial_data[parameters_financial_data]
view_dataframe_idiv_key_stats =  dataframe_idiv_key_stats[parameters_key_stats]

# %%
data = pd.concat([view_dataframe_idiv_financial_data,
                  view_dataframe_idiv_key_stats,
                  view_dataframe_idiv_summary_detail],
                 axis='columns')

# %%
def how_close_to_low(stock):
    high = stock['fiftyTwoWeekHigh']
    low = stock['fiftyTwoWeekLow']
    price = stock['previousClose']

    length = high - low
    
    return (price - low) / length

# %%
criteria = pd.DataFrame(index=data.index)

criteria['CTL'] = data.apply(how_close_to_low, axis='columns')
criteria['QR'] = data['quickRatio']
criteria['ROA'] = data['returnOnAssets']
criteria['ROE'] = data['returnOnEquity']
criteria['P/B'] = data['priceToBook']
criteria['DY'] = data['fiveYearAvgDividendYield']
criteria['DPR'] = data['payoutRatio']

criteria
# Out:
#                 CTL     QR      ROA      ROE       P/B    DY     DPR
# VIVT3.SA   0.281743   0.95  0.03682  0.06814  1.100432  6.13  0.8521
# CSNA3.SA   0.816119  1.209  0.06082  0.37965  4.892106   NaN   0.011
# BBSE3.SA   0.199305  1.268  0.23276  0.66174    7.4875  6.68  1.4436
# KLBN11.SA  0.817066  2.518  0.04132   -0.439  41.15108  3.11     NaN
# CYRE3.SA   0.613727  1.525  0.02841  0.33348  1.654093  3.26   0.397
# ITSA4.SA   0.532971  1.852  0.00559  0.12344  1.519507  4.66  0.4757
# ITUB3.SA   0.538148    NaN  0.00824  0.09911  1.720489  2.66    0.29
# TAEE11.SA  0.937931  2.665  0.11619  0.41083    2.0638  8.81     NaN
# TRPL4.SA   0.572695  3.909  0.10375   0.2426  1.225868  6.51   0.341
# BRDT3.SA   0.770723  1.282  0.10878  0.37238  2.107272   NaN  0.2805
# ITUB4.SA   0.565666    NaN  0.00824  0.09911  1.916433  2.83    0.29
# CCRO3.SA   0.298791  1.013  0.04796  0.01051  3.131524  4.63  5.0947
# MRVE3.SA   0.623009  1.273  0.03095  0.11145  1.489976   NaN  0.2975
# TIET11.SA  0.856354  0.914  0.11936  0.51495  3.778163   NaN     NaN
# SANB11.SA  0.698776    NaN   0.0148  0.17878  3.828673  5.79     NaN
# CMIG4.SA   0.633882   1.47  0.04798  0.11764  1.090925  3.96  0.4094
# BRAP4.SA   0.687816  2.757 -0.00461   0.0678  1.894014  4.23  0.3933
# PSSA3.SA   0.344086  0.742   0.0633  0.19588  1.678262  3.85  0.4087
# EGIE3.SA   0.447282  1.253  0.09863  0.37953  4.345351  5.72  0.3048
# SAPR11.SA  0.233202  1.165  0.07961  0.15191  4.810623   NaN     NaN
# QUAL3.SA   0.770029  2.078  0.10872  0.19852  4.972032  5.11  0.0029
# ENBR3.SA   0.783740  0.856  0.06065  0.15879  1.148181  2.99  0.1874
# CPLE6.SA   0.714740  0.986  0.05963  0.20261  0.956951  3.65  0.2216
# CIEL3.SA   0.172662  1.075   0.0063  0.04913  1.029663  3.57  0.3597
# SLCE3.SA   0.851404  0.808  0.06278  0.16655   2.70941   NaN  0.2277
# CPLE3.SA   0.756303  0.986  0.05963  0.20261  0.919934  3.97  0.2014
# BBAS3.SA   0.335749    NaN   0.0089   0.1212  0.679372   3.6  0.2992
# CSMG3.SA   0.300866  1.347  0.06848   0.1237  0.867395   3.1  0.2953
# BRSR6.SA   0.343874    NaN  0.00839  0.09017  0.600431  5.33  0.2312
# UNIP6.SA   0.940919  1.374  0.11261  0.22979  3.626314  9.13  0.3373
# MYPK3.SA   0.315868  0.773 -0.00048 -0.11505  0.521058  2.33     NaN
# SMLS3.SA   0.971580  0.818  0.04207  0.15335   2.28025  8.32  0.8035
# ABCB4.SA   0.586473    NaN  0.00801  0.07734  0.741548  5.98  0.2418
# ROMI3.SA   0.750386  1.178  0.04069  0.22206  2.277648   NaN  0.8178
# DIRR3.SA   0.476431  2.444  0.02792  0.11083  1.483431   NaN  1.0658
# SAPR4.SA   0.223729  1.165  0.07961  0.15191  0.951241  5.48  0.3273
# LEVE3.SA   0.843876  1.158   0.0727  0.09263  1.998858   5.5  0.5671
# TGMA3.SA   0.197230  2.466  0.07267  0.12244  1.911547   NaN  0.3037
# WIZS3.SA   0.175123  0.273  0.28424  0.80707   3.76616  6.19  0.5492

# %%
rank = pd.DataFrame(index=data.index)

rank['CTL'] = criteria['CTL'].rank(na_option='bottom')
rank['QR'] = criteria['QR'].rank(na_option='bottom', ascending=False)
rank['ROA'] = criteria['ROA'].rank(na_option='bottom', ascending=False)
rank['ROE'] = criteria['ROE'].rank(na_option='bottom', ascending=False)
rank['P/B'] = criteria['P/B'].rank(na_option='bottom')
rank['DY'] = criteria['DY'].rank(na_option='bottom', ascending=False)
rank['DPR'] = criteria['DPR'].rank(na_option='bottom')

rank['sum'] = rank.sum(axis='columns')

rank.sort_values(by='sum')
# Out:
#             CTL    QR   ROA   ROE   P/B    DY   DPR    sum
# TRPL4.SA   19.0   1.0   8.0   9.0  13.0   5.0  19.0   74.0
# SAPR4.SA    5.0  19.5  10.5  20.5   7.0  12.0  17.0   91.5
# BBSE3.SA    4.0  15.0   2.0   2.0  38.0   4.0  32.0   97.0
# WIZS3.SA    2.0  33.0   1.0   1.0  31.0   6.0  26.0  100.0
# CSMG3.SA    9.0  12.0  14.0  22.0   5.0  26.0  12.0  100.0
# EGIE3.SA   14.0  16.0   9.0   6.0  34.0  10.0  16.0  105.0
# QUAL3.SA   29.0   7.0   7.0  14.0  37.0  14.0   1.0  109.0
# TAEE11.SA  37.0   3.0   4.0   4.0  24.0   2.0  36.5  110.5
# CPLE3.SA   28.0  24.5  19.5  12.5   6.0  18.0   4.0  112.5
# UNIP6.SA   38.0  11.0   5.0  10.0  30.0   1.0  18.0  113.0
# TGMA3.SA    3.0   5.0  13.0  24.0  21.0  35.0  15.0  116.0
# CPLE6.SA   26.0  24.5  19.5  12.5   8.0  21.0   5.0  116.5
# BRDT3.SA   30.0  13.0   6.0   7.0  25.0  35.0   9.0  125.0
# CYRE3.SA   21.0   9.0  28.0   8.0  17.0  24.0  22.0  129.0
# CMIG4.SA   23.0  10.0  21.0  26.0  10.0  19.0  24.0  133.0
# BRSR6.SA   12.0  36.5  32.0  32.0   2.0  13.0   7.0  134.5
# PSSA3.SA   13.0  32.0  15.0  15.0  18.0  20.0  23.0  136.0
# ENBR3.SA   31.0  28.0  18.0  18.0  12.0  27.0   3.0  137.0
# ITSA4.SA   16.0   8.0  37.0  23.0  16.0  15.0  25.0  140.0
# VIVT3.SA    7.0  26.0  26.0  34.0  11.0   7.0  30.0  141.0
# BBAS3.SA   11.0  36.5  31.0  25.0   3.0  22.0  14.0  142.5
# CSNA3.SA   32.0  17.0  17.0   5.0  36.0  35.0   2.0  144.0
# ABCB4.SA   20.0  36.5  35.0  33.0   4.0   8.0   8.0  144.5
# CIEL3.SA    1.0  22.0  36.0  36.0   9.0  23.0  20.0  147.0
# MRVE3.SA   22.0  14.0  27.0  27.0  15.0  35.0  13.0  153.0
# DIRR3.SA   15.0   6.0  29.0  28.0  14.0  35.0  31.0  158.0
# BRAP4.SA   24.0   2.0  39.0  35.0  20.0  17.0  21.0  158.0
# LEVE3.SA   34.0  21.0  12.0  31.0  23.0  11.0  27.0  159.0
# SAPR11.SA   6.0  19.5  10.5  20.5  35.0  35.0  36.5  163.0
# SLCE3.SA   35.0  30.0  16.0  17.0  28.0  35.0   6.0  167.0
# CCRO3.SA    8.0  23.0  22.0  37.0  29.0  16.0  33.0  168.0
# SMLS3.SA   39.0  29.0  23.0  19.0  27.0   3.0  28.0  168.0
# ROMI3.SA   27.0  18.0  25.0  11.0  26.0  35.0  29.0  171.0
# TIET11.SA  36.0  27.0   3.0   3.0  32.0  35.0  36.5  172.5
# ITUB3.SA   17.0  36.5  33.5  29.5  19.0  29.0  10.5  175.0
# ITUB4.SA   18.0  36.5  33.5  29.5  22.0  28.0  10.5  178.0
# MYPK3.SA   10.0  31.0  38.0  38.0   1.0  30.0  36.5  184.5
# SANB11.SA  25.0  36.5  30.0  16.0  33.0   9.0  36.5  186.0
# KLBN11.SA  33.0   4.0  24.0  39.0  39.0  25.0  36.5  200.5
