# %%
# atualizado em
from datetime import date
print(date.today())
# Out:
# 2021-03-27

# %%
from utils import yahoo_symbol, create_rank_dataframe

idiv = [
'vivt3', 
'csna3', 
'bbse3', 
'klbn11', 
'cyre3', 
'itsa4', 
'itub3', 
'taee11', 
'trpl4', 
'brdt3', 
'itub4', 
'ccro3', 
'mrve3', 
'tiet11', 
'sanb11', 
'cmig4', 
'brap4', 
'pssa3', 
'egie3', 
'sapr11', 
'qual3', 
'enbr3', 
'cple6', 
'ciel3', 
'slce3', 
'cple3', 
'bbas3', 
'csmg3', 
'brsr6', 
'unip6', 
'mypk3', 
'smls3', 
'abcb4', 
'romi3', 
'dirr3', 
'sapr4', 
'leve3', 
'tgma3', 
'wizs3'
]

# %%
create_rank_dataframe(idiv)
# Out:
#             CTL  SOFG    QR    CR   ROA   ROE   P/B   P/E   P/S    DY   DPR  \
# TRPL4.SA   19.0   9.0   1.0   2.0   8.0   9.0  13.0   3.0  33.0   5.0  19.0
# TAEE11.SA  37.0  11.0   3.0   5.0   4.0   4.0  24.0   5.0  22.0   2.0  36.5
# CSMG3.SA    9.0  14.0  12.0  19.0  14.0  22.0   5.0  10.0  11.0  26.0  12.0
# SAPR4.SA    5.0  20.5  19.5  22.5  10.5  20.5   7.0   8.0  17.0  12.0  17.0
# CYRE3.SA   21.0  10.0   9.0   4.0  28.0   8.0  17.0   4.0  25.0  24.0  21.0
# CPLE3.SA   28.0  26.5  24.5  25.5  19.5  12.5   6.0   1.0   8.0  18.0   4.0
# BRDT3.SA   30.0  35.0  13.0  11.0   6.0   7.0  25.0   7.0   2.0  35.0   9.0
# CPLE6.SA   26.0  26.5  24.5  25.5  19.5  12.5   8.0   2.0  10.0  21.0   5.0
# EGIE3.SA   14.0  13.0  16.0  20.0   9.0   6.0  34.0  18.0  28.0  10.0  16.0
# ENBR3.SA   31.0   5.0  28.0  32.0  18.0  18.0  12.0  12.0   4.0  27.0   3.0
# WIZS3.SA    2.0  37.0  33.0  33.0   1.0   1.0  31.0   6.0  16.0   6.0  26.0
# ...
