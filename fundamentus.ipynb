# %%
import requests
import pandas as pd

url = 'http://fundamentus.com.br/resultado.php'
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

r = requests.get(url, headers=header)


data = pd.read_html(r.text)[0]

all_b3_codes = data['Papel'].to_list()

# %%
data
# Out:
#       Papel  Cotação          P/L    P/VP      PSR Div.Yield  P/Ativo  \
# 0     VNET3      0.0      0.00000     0.0      0.0     0,00%        0
# 1    EQMA5B      0.0      0.00000     0.0      0.0     0,00%        0
# 2     ODER3      0.0      0.00000     0.0      0.0     0,00%        0
# 3     CLAN3      0.0      0.00000     0.0      0.0     0,00%        0
# 4     MNSA3     42.0      0.00000     0.0      0.0     0,00%        0
# ..      ...      ...          ...     ...      ...       ...      ...
# 936   LWSA3   2300.0  68215.00000  1998.0  27582.0     0,12%     9272
# 937   PRBC4   1454.0  80837.00000  3912.0      0.0     0,00%        0
# 938  UBBR11   1475.0      1.20181   391.0      0.0     0,00%        0
# 939   UBBR3   1800.0      1.46661   477.0      0.0     0,00%        0
# 940   DMVF3    897.0      3.69032    54.0    452.0     0,00%      312
#
#      P/Cap.Giro   P/EBIT  P/Ativ Circ.Liq  ...  EV/EBITDA  Mrg Ebit Mrg. Líq.  \
# 0           0.0      0.0                0  ...        0.0     0,00%     0,00%
# 1           0.0      0.0                0  ...        0.0     0,00%     0,00%
# 2           0.0      0.0                0  ...        0.0     0,00%     0,00%
# 3           0.0      0.0                0  ...        0.0     0,00%     0,00%
# 4           0.0      0.0                0  ...        0.0  -208,15%  -362,66%
# ..          ...      ...              ...  ...        ...       ...       ...
# 936      3773.0  31115.0            46267  ...    13211.0     8,86%     4,04%
# 937         0.0      0.0                0  ...        0.0     0,00%     0,00%
# 938         0.0      0.0                0  ...        0.0     0,00%     0,00%
# 939         0.0      0.0                0  ...        0.0     0,00%     0,00%
# 940       275.0    775.0             -334  ...      279.0     5,83%     0,01%
#
#     Liq. Corr.     ROIC      ROE     Liq.2meses       Patrim. Líq  \
# 0            0    0,00%    5,17%            000   9.490.850.00000
# 1            0    0,00%   23,36%            000   2.997.240.00000
# 2            0    0,00%   41,79%            000     284.266.00000
# 3            0    0,00%   -1,05%            000   1.012.240.00000
# 4          363  -13,50%  145,70%            000      -9.105.00000
# ..         ...      ...      ...            ...               ...
# 936        179    4,30%    2,93%  270.431.00000     673.973.00000
# 937          0    0,00%    4,84%            000   1.210.880.00000
# 938          0    0,00%    0,33%            000  10.317.200.00000
# 939          0    0,00%    0,33%            000  10.317.200.00000
# 940        152    5,25%    0,01%    2.565.55000     836.159.00000
#
#     Dív.Brut/ Patrim.  Cresc. Rec.5a
# 0                 0.0        -17,77%
# 1                 0.0          7,29%
# 2                 0.0         10,81%
# 3                 0.0        -63,96%
# 4              -652.0        -41,11%
# ..                ...            ...
# 936              23.0         24,50%
# 937               0.0         11,60%
# 938               0.0         10,58%
# 939               0.0         10,58%
# 940              16.0        -11,29%
#
# [941 rows x 21 columns]
